# %%
Building block of the object orinted program



We are going to learn the below topic:-
1. Class
2. Object
3. Method
4. Attribute
5. Abstraction
6. Polimorphism
7. Encapsulation
8. Inheritence
9. Aggregation

# %% [markdown]
# ### How to define the class

# %%
class ClassName:
    '''
     docuemntation string
     variales: instance,static and local variale
     methods: instance, static and class method
    '''
    
print(ClassName.__doc__)
help(ClassName)
# Out:
#      docuemntation string
#      variales: instance,static and local variale
#      methods: instance, static and class method
#
# Help on class ClassName in module __main__:
#
# class ClassName(builtins.object)
#  |  docuemntation string
#  |  variales: instance,static and local variale
#  |  methods: instance, static and class method
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)

# %%
from IPython.display import Image,display
display(Image('naming_std.png'))

# %% [markdown]
# ### Constructor and self variable

# %%
# ☕Constructor is a special method in python.
# ☕ The name of the constructor should be __init__(self)
# ☕ Constructor will be executed automatically at the time of object creation.
# ☕ The main purpose of constructor is to declare and initialize instance variables.
# ☕ Per object constructor will be exeucted only once.
# ☕ Constructor can take atleast one argument(atleast self)
# ☕ Constructor is optional

# self is the default variable which is always pointing to current object (like this keyword in Java)

# Note:
# 1. self should be first parameter inside constructor
# def __init__(self):
# 2. self should be first parameter inside instance methods
# def talk(self):


class Test:
    def __init__(self,name,city):
        self.name=''
        self.city=''
    
    def details(self):
        print(id(self))
        print(self.name,self.city)
        
t = Test('Radha','Gokuldham')
print(id(t))
print(t.details())
# Out:
# 2304394409872
# 2304394409872
#
# None

# %%
## Example

class Atm:
    def __init__(self,name):
        self.name = name
        self.pin = 0
        self.accno = 20456183100
        self.bal = 50000
#         self.menu()
        
    def menu(self):
        user = int(input('''
        Welcome to dk bank
        
        1. Create a new pin
        2. Change pin
        3. Check balance
        4. Withdrow Money
        5. Exit
        '''))
        if user==1:
            self.create_pin()
        elif user==2:
            self.change_pin()
        elif user==3:
            self.check_bal()
        elif user==4:
            self.withdrow()
        else:
            exit()
    
    def create_pin(self):
        new_pin = int(input('Enter new pin: '))
        self.pin = new_pin
        print('pin created...')
        self.menu()
        
    def change_pin(self):
        old_pin = int(input('Enter old pin: '))
        if old_pin!=self.pin:
            self.menu()
        else:
            new_pin = int(input('Enter new pin: '))
            self.pin = new_pin
            print('pin updated...')
            self.menu()
            
    def check_bal(self):
        print('Balance: ',self.bal)
        if (input('Want to exit: press y to exit or press n to enter')!='n'):
            exit()
        else:
            self.menu()
        
    def withdrow(self):
        w_bal = int(input('Enter Amount: '))
        if w_bal>=self.bal:
            print('Insufficient Balance')
        else:
            self.bal = self.bal-new_bal
            print('Total Amount: ',self.bal)
            exit()

# %%
len(L) # function ->bcos it is outside the list class
# L.append()# method -> bcos it is inside the list class

# %%
obj1 = Atm('dk') 
obj2 = Atm('vk')
print(id(obj1))
print(id(obj2))
# Out:
# 2958390283984
# 2958390286224

# %%
obj1.name
# Out:
# 'dk'

# %%
class Temp:
    def __init__(self,name):
        self.name = name;
    
t = Temp('dksharma')
print(t)

# %%
class Temp:
    def __init__(self,name):
        self.name = name
    
    def __str__(self):
        return 'name: '+self.name
    
t = Temp('dksharma')
print(t)
# Out:
# name: dksharma

# %%
## Attributes create and access from outside of the class
# we can access instance variable from outside of the class

atm = Atm('sharma')
print(atm.bal)
# Out:
# 50000

# %%
atm.bal=970

# %%
print(atm.check_bal())
# Out:
# Balance:  970
# Want to exit: press y to exit or press n to entery
# None

# %% [markdown]
# ### Reference Variable

# %%
# Reference variable holds the object
# we can create object without variable as well
# An object can have multiple referece variables
# Assiging a new reference variable to an existing object does not create new obj

# %%
class Person:
    def __init__(self):
        self.name='dk'
        self.city ='chapra'
        
Person()
print(id(Person()))
p = Person()
print(id(p))

q = p
print(id(q))

print(p.name)
print(q.name)
q.name='dharmendra'
print(p.name)
# Out:
# 2304386672400
# 2304386674512
# 2304386674512
# dk
# dk
# dharmendra

# %% [markdown]
# #### Pass by reference

# %%
class Person:
    def __init__(self,name,gender):
        self.name = name
        self.gender = gender
        
# outside of the class
def myfun(person):
    print('Name:{}, City:{}'.format(person.name,person.gender))
    
def myfun1():
    person = Person('rajan','motihari')
    return person

p = Person('dk','chapra')
myfun(p)

p1 = myfun1()
print(p1.name)
# Out:
# Name:dk, City:chapra
# rajan

# %% [markdown]
# #### Collection of object

# %%
## Collection of object

class Person:
    def __init__(self,name,city):
        self.name = name
        self.city = city

p1 = Person('dk','chapra')
p2 = Person('ss','nalanda')
p3 = Person('rs','motihari')
p4 = Person('vk','chapra')


l = [p1,p2,p3,p4]
for obj in l:
    print(obj.name+'-'+obj.city)

# using dict
dic ={'p1':p1,'p2':p2}
for obj in dic:
    print(dic[obj].name)
# Out:
# dk-chapra
# ss-nalanda
# rs-motihari
# vk-chapra
# dk
# ss

# %% [markdown]
# ## Types of Variables

# %% [markdown]
# ##### 1. Instance Variable ( Object Level variable )
# ##### 2. Static Variable (  Class Level Variable )
# ##### 3. Local Variable ( Method Level Variable )

# %%
#1. Instance Variable
# For every object a seperate copy of instance variable ceates
# It's value varied from object to object

# Where we can declare Instance variables:
# 1. Inside Constructor by using self variable
# 2. Inside Instance Method by using self variable
# 3. Outside of the class by using object reference variable

# exp
class Test:
    def __init__(self):
        self.name='dharmendra' #instance variable inside construtor
        self.city=''
    
    def call(self):
        self.pin=1234  # instance variable using the self inside method
        print(f'Name:{self.name},city:{self.city},pin:{self.pin}')
    
t = Test()
print(t.name)
# print(t.pin)
t.call()
t.pin
t.state='bihar' # instance variable uisng the ref variable
# Out:
# dharmendra
# Name:dharmendra,city:,pin:1234
# 1234

# %%
#2 static variable

# If the value of a variable is not varied from object to object, such type of variables we have to declare with in the class 
  # directly but outside of methods. Such type of variables are called Static variables.
# For total class only one copy of static variable will be created and shared by all objects of that class.
# We can access static variables either by class name or by object reference. But recommended to use class name.


How to declare static varianles.

1. In general we can declare within the class directly but from out side of any method
2. Inside constructor by using class name
3. Inside instance method by using class name
4. Inside classmethod by using either class name or cls variable
5. Inside static method by using class name

# %%
class TestVariable:
    svar=10
    def __init__(self):
        TestVariable.a=10
    def insmethod(self):
        TestVariable.b=100
        
    @classmethod
    def classmeth(self):
        TestVariable.c=11
        cls.c1=111
    @staticmethod
    def staticmeth(self):
        TestVariable.s=9
        
t1 = TestVariable()
t2 = TestVariable()

print(t1.svar)
t1.svar=111111
TestVariable.svar=199
print(t2.svar)
t3 = TestVariable()
print(t3.svar)
# Out:
# 10
# 199
# 199

# %%
print(t1.a)
t1.a=100
print(t2.a)
# Out:
# 100
# 10

# %%
t.svar=34
t1 = TestVariable()
t1.svar
# Out:
# 10

# %%
print(TestVariable.__dict__)
# Out:
# {'__module__': '__main__', 'svar': 10, '__init__': <function TestVariable.__init__ at 0x000001A9B6C88D30>, 'insmethod': <function TestVariable.insmethod at 0x000001A9B6C88B80>, 'classmeth': <classmethod(<function TestVariable.classmeth at 0x000001A9B6C88DC0>)>, 'staticmeth': <staticmethod(<function TestVariable.staticmeth at 0x000001A9B6C88EE0>)>, '__dict__': <attribute '__dict__' of 'TestVariable' objects>, '__weakref__': <attribute '__weakref__' of 'TestVariable' objects>, '__doc__': None, 'a': 10}

# %%
# 1	class Test:
# 2	    a=100
# 3	    def __init__(self):
# 4	        self.a=109
# 5	        print(self.a)
# 6	        print(Test.a)
# 7	        
# 8	    def m2(self):
# 9	        print(Test.a)
# 10	        print(self.a)
# 11	        
# 12	t = Test()
# 13	t.m2()
# 14	print(t.a)
# 15	print(Test.a)
